# %%
import numpy as np
import pandas as pd
from pathlib import Path
# %matplotlib inline

# %% [markdown]
# # Return Forecasting: Read Historical lenovo prices
# In this notebook, you will load historical lenovo price data and apply time series analysis and modeling to determine whether there is any predictable behavior.

# %%
# Futures contract on the Yen-dollar exchange rate:

lenovo = pd.read_csv(
    Path("lenovo.csv"), index_col="Date", infer_datetime_format=True, parse_dates=True
)

lenovo.head()
# Out:
#             Close    Volume   Open   High    Low
# Date
# 2014-12-17  25.82  126300.0  25.52  26.05  25.42
# 2014-12-18  25.56   76500.0  25.65  25.67  25.50
# 2014-12-19  26.38   36200.0  26.18  26.40  26.00
# 2014-12-22  26.16   36200.0  26.28  26.30  26.05
# 2014-12-23  25.95   47800.0  25.92  26.07  25.91

# %%
# Trim the dataset to begin on December 15th, 2015
lenovo = lenovo.loc["2014-12-15":, :]
lenovo.head(500)
# Out:
#             Close    Volume   Open   High    Low
# Date
# 2014-12-17  25.82  126300.0  25.52  26.05  25.42
# 2014-12-18  25.56   76500.0  25.65  25.67  25.50
# 2014-12-19  26.38   36200.0  26.18  26.40  26.00
# 2014-12-22  26.16   36200.0  26.28  26.30  26.05
# 2014-12-23  25.95   47800.0  25.92  26.07  25.91
# ...           ...       ...    ...    ...    ...
# 2016-12-05  12.26  341052.0  12.26  12.29  12.23
# 2016-12-06  12.25   59528.0  12.16  12.31  12.16
# 2016-12-07  12.33  190973.0  12.11  12.34  12.11
# 2016-12-08  12.22   42841.0  12.40  12.40  12.20
# 2016-12-09  12.23   21643.0  12.38  12.38  12.20
#
# [500 rows x 5 columns]

# %% [markdown]
#  # Return Forecasting: Initial Time-Series Plotting

# %% [markdown]
#  Start by plotting the "Close/Last" price. Do you see any patterns, long-term and/or short?

# %%
# Plot just the "Close/Last" column from the dataframe:
lenovo['Close'].plot(figsize=(17, 10), title="lenovo Price")

# %% [markdown]
# *Answer*
#  * Based on the plot above, we can see a long-term strengthening of the lenovo prices. There do seem to be some more medium, 1-3 year consistent trends, but on a daily basis, there are a lot of short-term ups and downs.

# %% [markdown]
# ---

# %% [markdown]
# # Decomposition Using a Hodrick-Prescott Filter

# %% [markdown]
#  Using a Hodrick-Prescott Filter, decompose the Settle price into a trend and noise.

# %%
import statsmodels.api as sm

# Apply the Hodrick-Prescott Filter by decomposing the "Close" price into two separate series:
lenovo_noise, lenovo_trend = sm.tsa.filters.hpfilter(lenovo['Close'])

# %%
# Create a dataframe of just the settle price, and add columns for "noise" and "trend" series from above:
lenovo_decomp = lenovo[["Close"]].copy()
lenovo_decomp["noise"] = lenovo_noise
lenovo_decomp["trend"] = lenovo_trend
lenovo_decomp.head()
# Out:
#             Close     noise      trend
# Date
# 2014-12-17  25.82 -0.017592  25.837592
# 2014-12-18  25.56 -0.331372  25.891372
# 2014-12-19  26.38  0.434859  25.945141
# 2014-12-22  26.16  0.161320  25.998680
# 2014-12-23  25.95 -0.102044  26.052044

# %%
# Plot the Settle Price vs. the Trend
lenovo_decomp[["Close", "trend"]]["2015-12-01":].plot(figsize=(17, 10), title="Close vs. Trend")

# %% [markdown]
# Smoothing with the HP Filter and plotting the resulting trend against the actual futures returns, we can see that there's a lot of short term fluctuations that deviate around this trend. Perhaps these would represent profitable trading opportunities: For example, when the blue line deviates far below the orange, we can see this as a sign that the Yen is temporarily more undervalued than it should be (and, therefore, we'd see this as a short-term buying opportunity).

# %%
# Plot the Settle Noise
lenovo_decomp[["noise"]].plot(figsize=(17, 10), title="Noise")

# %% [markdown]
# ---

# %% [markdown]
# # Forecasting Returns using an ARMA Model

# %% [markdown]
# Using futures Settle *Returns*, estimate an ARMA model
#
# 1. ARMA: Create an ARMA model and fit it to the returns data. Note: Set the AR and MA ("p" and "q") parameters to p=2 and q=1: order=(2, 1).
# 2. Output the ARMA summary table and take note of the p-values of the lags. Based on the p-values, is the model a good fit (p < 0.05)?
# 3. Plot the 5-day forecast of the forecasted returns (the results forecast from ARMA model)

# %%
# Create a series using "Close" price percentage returns, drop any nan"s, and check the results:
# (Make sure to multiply the pct_change() results by 100)
# In this case, you may have to replace inf, -inf values with np.nan"s
returns = (lenovo[["Close"]].pct_change() * 100)
returns = returns.replace(-np.inf, np.nan).dropna()
returns.tail()
# Out:
#                Close
# Date
# 2019-12-10  1.175549
# 2019-12-11  0.852053
# 2019-12-12  2.150538
# 2019-12-13 -0.375940
# 2019-12-16  2.264151

# %%
import statsmodels.api as sm
from statsmodels.tsa.arima_model import ARMA

# Estimate and ARMA model using statsmodels (use order=(2, 1))
model = ARMA(returns.values, order=(2,1))

# Fit the model and assign it to a variable called results
results = model.fit()

# %%
# Output model summary results:
results.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                               ARMA Model Results
# ...
# Dep. Variable:                      y   No. Observations:                 1257
# Model:                     ARMA(2, 1)   Log Likelihood               -2706.505
# Method:                       css-mle   S.D. of innovations              2.084
# Date:                Wed, 18 Dec 2019   AIC                           5423.011
# Time:                        22:13:45   BIC                           5448.693
# Sample:                             0   HQIC                          5432.663
#
# ...
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -0.0293      0.064     -0.461      0.645      -0.154       0.095
# ar.L1.y       -0.7318      0.266     -2.756      0.006      -1.252      -0.211
# ar.L2.y        0.0755      0.028      2.680      0.007       0.020       0.131
# ...

# %%
# Plot the 5 Day Returns Forecast
pd.DataFrame(results.forecast(steps=5)[0]).plot(figsize=(8, 8), title="5 Day Returns Forcust")

# %% [markdown]
# ## Question:
#
# #### Based on the p-value, is the model a good fit?
#
# ## Answer:

# %% [markdown]
# #### Based on the p-value, the model is not a good fit.

# %% [markdown]
# ---

# %% [markdown]
# # Forecasting the Settle Price using an ARIMA Model

# %% [markdown]
#  1. Using the *raw* Yen **Settle Price**, estimate an ARIMA model.
#      1. Set P=5, D=1, and Q=1 in the model (e.g., ARIMA(df, order=(5,1,1))
#      2. P= # of Auto-Regressive Lags, D= # of Differences (this is usually =1), Q= # of Moving Average Lags
#  2. Output the ARIMA summary table and take note of the p-values of the lags. Based on the p-values, is the model a good fit (p < 0.05)?
#  3. Construct a 5 day forecast for the Settle Price. What does the model forecast will happen to the Japanese Yen in the near term?

# %%
from statsmodels.tsa.arima_model import ARIMA

# Estimate and ARIMA Model:
# Hint: ARIMA(df, order=(p, d, q))
model = ARIMA(lenovo["Close"], order=(5, 1, 1))


# Fit the model
results = model.fit()
# Out:
# C:\Users\armen\Anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:219: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)
# C:\Users\armen\Anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:219: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)

# %%
# Output model summary results:
results.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                              ARIMA Model Results
# ...
# Dep. Variable:                D.Close   No. Observations:                 1257
# Model:                 ARIMA(5, 1, 1)   Log Likelihood                -575.691
# Method:                       css-mle   S.D. of innovations              0.383
# Date:                Wed, 18 Dec 2019   AIC                           1167.381
# Time:                        22:13:47   BIC                           1208.473
# Sample:                             1   HQIC                          1182.825
#
# ...
#                     coef    std err          z      P>|z|      [0.025      0.975]
# ---------------------------------------------------------------------------------
# const            -0.0096      0.013     -0.708      0.479      -0.036       0.017
# ar.L1.D.Close     1.0052      0.069     14.654      0.000       0.871       1.140
# ...

# %%
# Plot the 5 Day Price Forecast
pd.DataFrame(results.forecast(steps=5)[0]).plot(figsize=(8, 8), title="5 Day Futures Price Forecast")

# %% [markdown]
# ### What does the model forecast will happen to the lenovo price in the near term?

# %% [markdown]
# ### Based on model forcast the lenovo stock price will go down in value

# %% [markdown]
# ---

# %% [markdown]
# # Volatility Forecasting with GARCH
#
# Rather than predicting returns, let's forecast near-term **volatility** of Japanese Yen futures returns. Being able to accurately predict volatility will be extremely useful if we want to trade in derivatives or quantify our maximum loss.
#
# Using futures Settle *Returns*, estimate an GARCH model
#
# 1. GARCH: Create an GARCH model and fit it to the returns data. Note: Set the parameters to p=2 and q=1: order=(2, 1).
# 2. Output the GARCH summary table and take note of the p-values of the lags. Based on the p-values, is the model a good fit (p < 0.05)?
# 3. Plot the 5-day forecast of the volatility.

# %%
import arch as arch
from arch import arch_model

# %%
# Estimate a GARCH model:
model = arch_model(returns, mean="Zero", vol="GARCH", p=2, q=1, rescale=False)

# Fit the model
res = model.fit(disp="off")

# %%
# Summarize the model results
res.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                        Zero Mean - GARCH Model Results
# ...
# Dep. Variable:                  Close   R-squared:                       0.000
# Mean Model:                 Zero Mean   Adj. R-squared:                  0.001
# Vol Model:                      GARCH   Log-Likelihood:               -2643.84
# Distribution:                  Normal   AIC:                           5295.68
# Method:            Maximum Likelihood   BIC:                           5316.23
#                                         No. Observations:                 1257
# Date:                Wed, Dec 18 2019   Df Residuals:                     1253
# Time:                        22:13:49   Df Model:                            4
#                                Volatility Model
# ...
#                  coef    std err          t      P>|t|       95.0% Conf. Int.
# -----------------------------------------------------------------------------
# ...

# %%
# Find the last day of the dataset
last_day = returns.index.max().strftime('%Y-%m-%d')
last_day
# Out:
# '2019-12-16'

# %%
# Create a 5 day forecast of volatility
forecast_horizon = 5
# Start the forecast using the last_day calculated above
forecasts = res.forecast(start=last_day, horizon=forecast_horizon)
forecasts

# %%
# Annualize the forecast
intermediate = np.sqrt(forecasts.variance.dropna() * 252)
intermediate.tail()
# Out:
#                   h.1        h.2        h.3        h.4       h.5
# Date
# 2019-12-16  31.955349  31.957723  31.960088  31.962444  31.96479

# %%
# Transpose the forecast so that it is easier to plot
final = intermediate.dropna().T
final.head()
# Out:
# Date  2019-12-16
# h.1    31.955349
# h.2    31.957723
# h.3    31.960088
# h.4    31.962444
# h.5    31.964790

# %%
# Plot the final forecast
final.plot(figsize=(8, 8), title="5 day forecast of volatility GARCH")

# %% [markdown]
# ---

# %% [markdown]
# # Conclusions

# %% [markdown]
# 1. Based on your time series analysis, would you buy the yen now?
#
# 2. Is the risk of the yen expected to increase or decrease?
#
# 3. Based on the model evaluation, would you feel confident in using these models for trading?

# %% [markdown]
# 1. Based on time series analysis I would by the yen now.
#
# 2. Yes, the risk expected to increase.
#
# 3. Based on the model evaluation, I feel confident uding only GARCH model for trading. ARMA and ARIMA are not good fit.
